# %%
import math
num = 16
result=(math.sqrt(num))
print("Square root of",num,"is",result)
# Out:
# Square root of 16 is 4.0

# %%
import math

base = 2
exponent = 3
result_pow = math.pow(base, exponent)

print(f"{base} raised to the power of {exponent} is {result_pow}")
# Out:
# 2 raised to the power of 3 is 8.0

# %%
import math
num = 7.8
math.floor(num)
math.ceil(num)
# Out:
# 8

# %%
#Math Functions
import math # Imports the math module for mathematical functions
num = 16 # Initializes a variable 'num' with the value 16
math.sqrt(16) # Calculates the square root of 16 (result is 4.0)
math.pow(2,3) # Calculates 2 raised to the power of 3 (result is 8.0)
math.floor(7.8) # Returns the largest integer less than or equal to 7.8 (result is 7)
math.ceil(7.8) # Returns the smallest integer greater than or equal to 7.8 (result is 8)
math.fabs(-5) # Returns the absolute value of -5 (result is 5.0)
# Out:
# 5.0

# %%
#RANDOM
import random
dice = random.randint(1,6) #outputs random number between 1 to 6 when run
print(dice)
# Out:
# 5

# %%
student = ["Shivashish", "Srijan", "Parvez", "Prakash"]
student = random.choice(student)
print("Congrats",student)
# Out:
# Congrats Srijan

# %%
#Date&Time
import datetime
Current = datetime.datetime.now()
Today = datetime.date.today()
print("Current Date:", Current.day)
print("Current Month:", Current.month)
print("Current Time:", Current.time())
print("Current Year:", Current.year)
# Out:
# Current Date: 30
# Current Month: 1
# Current Time: 04:52:22.009307
# Current Year: 2026

# %%
#India Date & Time Program if run on online compiler
#Date&Time
import datetime
from zoneinfo import ZoneInfo  # Required for timezone support

# Get current date and time specifically for India
# 'Asia/Kolkata' is the standard IANA identifier for IST
Current = datetime.datetime.now(ZoneInfo("Asia/Kolkata"))
print("Current Date:", Current.day)
print("Current Month:", Current.month)
print("Current Time:", Current.time())
print("Current Year:", Current.year)
# Out:
# Current Date: 30
# Current Month: 1
# Current Time: 10:23:15.434137
# Current Year: 2026

# %%
from collections import Counter
Fruits = ["banana","apple","banana","apple","mango","mango","banana"] # Creates a list of strings called 'Fruits'
count = Counter(Fruits) # Uses Counter to count the occurrences of each item in the 'Fruits' list
print(count) # Prints the resulting Counter object, showing item counts
# Out:
# Counter({'banana': 3, 'apple': 2, 'mango': 2})

# %%
from collections import Counter
text = "hello"
count = Counter(text)
print(count)
# Out:
# Counter({'l': 2, 'h': 1, 'e': 1, 'o': 1})

# %%
from collections import Counter
Sentence = "Python is easy and python is powerfull"
words = Sentence.split()
print (Sentence)
count = Counter(words)
print(count)
# Out:
# Python is easy and python is powerfull
# Counter({'is': 2, 'Python': 1, 'easy': 1, 'and': 1, 'python': 1, 'powerfull': 1})

# %%
#create number repeating numbers and then start counter on this
from collections import Counter
number = [1,2,2,4,4,5,3,2,1,6,5,4,8,9,3,7,8,9,1,5]
count=Counter(number)
print(count)
# Out:
# Counter({1: 3, 2: 3, 4: 3, 5: 3, 3: 2, 8: 2, 9: 2, 6: 1, 7: 1})

# %% [markdown]
# Here are some common `os` module functions and their purposes, which are analogous to terminal commands:
#
# *   `os.getcwd()`: Returns a string representing the current working directory of the process. (Similar to `pwd` in Linux/macOS or `cd` without arguments in Windows).
# *   `os.listdir(path='.')`: Returns a list containing the names of the entries in the directory given by `path`. If `path` is not specified, it defaults to the current directory. (Similar to `ls` in Linux/macOS or `dir` in Windows).
# *   `os.mkdir(path)`: Creates a directory named `path` with the specified numeric mode. (Similar to `mkdir`).
# *   `os.remove(path)`: Removes (deletes) the file `path`. (Similar to `rm` for files).
# *   `os.rmdir(path)`: Removes (deletes) the empty directory `path`. (Similar to `rmdir` or `rm -d`).
# *   `os.rename(src, dst)`: Renames the file or directory `src` to `dst`. (Similar to `mv` or `rename`).
# *   `os.path.exists(path)`: Returns `True` if `path` refers to an existing path or an open file descriptor, `False` otherwise.
# *   `os.path.join(path, *paths)`: Joins one or more path components intelligently. This is very useful for creating platform-independent file paths.

# %%
import os
current_path = os.getcwd()
print(current_path)
# Out:
# /content

# %%
import os
item=os.listdir()
print(item)
# Out:
# ['.config', 'sample_data']

# %%
import os
folder_name="myfolder"
if not os.path.exists(folder_name):
  os.mkdir(folder_name)
  print("folder created successfully")
else:
  print("folder already exists")
# Out:
# folder created successfully

# %%
import os
file_path = '/content/myfolder/os.ipnyb'
if os.path.exists(file_path):
  print(f"The file '{file_path}' exists.")
else:
  print(f"The file '{file_path}' does not exist.")
# Out:
# The file '/content/myfolder/os.ipnyb' exists.

# %%
#1. Generate random numbers
#2. Check which numbers are even_odd
#3. Round numbers using math
#4. count how many times numbers appears
#5. save the result in file

import random
import math
from collections import Counter
import os

# 1. Generate random numbers
print("Generating 10 random numbers between 1 and 100:")
random_numbers = [random.randint(1, 100) for _ in range(10)]
print(f"Generated Numbers: {random_numbers}")

results = []
results.append("Generated Numbers and Analysis:")
results.append(f"Generated Numbers: {random_numbers}")

# 2. Check which numbers are even_odd and 3. Round numbers using math
print("\nAnalyzing numbers for even/odd and rounding:")
for num in random_numbers:
    even_odd = "Even" if num % 2 == 0 else "Odd"
    floor_num = math.floor(num)
    ceil_num = math.ceil(num)
    rounded_num = round(num)
    analysis = f"Number: {num}, Status: {even_odd}, Floor: {floor_num}, Ceil: {ceil_num}, Rounded: {rounded_num}"
    print(analysis)
    results.append(analysis)

# 4. Count how many times numbers appears
print("\nCounting occurrences of each number:")
number_counts = Counter(random_numbers)
print(f"Number Counts: {number_counts}")
results.append(f"\nNumber Counts: {number_counts}")

# 5. Save the result in file
file_name = "random_number_analysis.txt"

# Create 'myfolder' if it doesn't exist (assuming it's where other files are created)
folder_name = "myfolder"
if not os.path.exists(folder_name):
    os.mkdir(folder_name)
    print(f"Created folder: {folder_name}")

file_path = os.path.join(folder_name, file_name)

try:
    with open(file_path, "w") as f:
        for line in results:
            f.write(line + "\n")
    print(f"\nResults successfully saved to '{file_path}'")
except IOError as e:
    print(f"Error saving file: {e}")
# Out:
# Generating 10 random numbers between 1 and 100:
# Generated Numbers: [63, 28, 85, 80, 57, 22, 54, 44, 29, 76]
#
# Analyzing numbers for even/odd and rounding:
# Number: 63, Status: Odd, Floor: 63, Ceil: 63, Rounded: 63
# Number: 28, Status: Even, Floor: 28, Ceil: 28, Rounded: 28
# Number: 85, Status: Odd, Floor: 85, Ceil: 85, Rounded: 85
# Number: 80, Status: Even, Floor: 80, Ceil: 80, Rounded: 80
# Number: 57, Status: Odd, Floor: 57, Ceil: 57, Rounded: 57
# Number: 22, Status: Even, Floor: 22, Ceil: 22, Rounded: 22
# Number: 54, Status: Even, Floor: 54, Ceil: 54, Rounded: 54
# Number: 44, Status: Even, Floor: 44, Ceil: 44, Rounded: 44
# Number: 29, Status: Odd, Floor: 29, Ceil: 29, Rounded: 29
# Number: 76, Status: Even, Floor: 76, Ceil: 76, Rounded: 76
#
# Counting occurrences of each number:
# Number Counts: Counter({63: 1, 28: 1, 85: 1, 80: 1, 57: 1, 22: 1, 54: 1, 44: 1, 29: 1, 76: 1})
#
# Results successfully saved to 'myfolder/random_number_analysis.txt'

# %%
# 1. generate random password
# 2. check password strength
# 3. count characters in password
# 4. calculate strength score using math
# 5. save result in a file using os

import random
import math
import os

# characters manually defined
letters = "abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ"
digits = "0123456789"
specials = "!@#$%^&*()_+"
all_chars = letters + digits + specials

# generate password
password = ""
for i in range(12):
    password += random.choice(all_chars)

# count characters
char_count = {}
for ch in password:
    char_count[ch] = char_count.get(ch, 0) + 1

# check strength
upper = False
lower = False
digit = False
special = False

for ch in password:
    if ch in "ABCDEFGHIJKLMNOPQRSTUVWXYZ":
        upper = True
    elif ch in "abcdefghijklmnopqrstuvwxyz":
        lower = True
    elif ch in digits:
        digit = True
    elif ch in specials:
        special = True

strength = upper + lower + digit + special

# strength score using math
score = round(math.log(len(password)) * strength, 2)

# save result using os
os.makedirs("output", exist_ok=True)
f = open("output/password.txt", "w")
f.write("Password: " + password + "\n")
f.write("Character Count: " + str(char_count) + "\n")
f.write("Strength Score: " + str(score))
f.close()

print("Password saved in output/password.txt")
# Out:
# Password saved in output/password.txt
